# %%
from strategies import get_price_and_rsi, rsi_strategy_1
import pandas as pd

# %%
# get rsi and price data
h1_data = get_price_and_rsi(60, 1609459200, 1640995200)
h4_data = get_price_and_rsi(240)

# %%
buy_20_sell_80_h4 = rsi_strategy_1(h4_data, 20, 80)
df = pd.DataFrame(data = buy_20_sell_80_h4["trades"])
df
# Out:
#    side    entry     exit   profit  cum_profit
# 0   buy  42059.0  55029.0  12970.0     12970.0
# 1  sell  54844.0  47368.0   7476.0     20446.0
# 2   buy  48284.0  34847.0 -13437.0      7009.0
# 3   buy  35072.0  43867.0   8795.0     15804.0
# 4  sell  43876.0  44887.0  -1011.0     14793.0

# %%
buy_30_sell_70_h1 = rsi_strategy_1(h1_data, 30, 70)
df = pd.DataFrame(data = buy_30_sell_70_h1["trades"])
df
# Out:
#     side    entry     exit  profit  cum_profit
# 0    buy  41998.0  41769.0  -229.0      -229.0
# 1    buy  40648.0  40202.0  -446.0      -675.0
# 2    buy  38356.0  34938.0 -3418.0     -4093.0
# 3    buy  35323.0  41489.0  6166.0      2073.0
# 4   sell  41668.0  43066.0 -1398.0       675.0
# 5   sell  43188.0  43367.0  -179.0       496.0
# 6   sell  43288.0  44661.0 -1373.0      -877.0
# 7   sell  43877.0  40699.0  3178.0      2301.0
# 8    buy  39048.0  38867.0  -181.0      2120.0
# 9    buy  38344.0  41232.0  2888.0      5008.0
# 10  sell  41936.0  42241.0  -305.0      4703.0
# 11  sell  42267.0  37717.0  4550.0      9253.0
# 12  sell  41766.0  43026.0 -1260.0      7993.0
# 13  sell  44918.0  46150.0 -1232.0      6761.0
# 14  sell  47452.0  48015.0  -563.0      6198.0
# 15  sell  47664.0  44950.0  2714.0      8912.0
# 16   buy  44641.0  44176.0  -465.0      8447.0
# 17   buy  43877.0  43514.0  -363.0      8084.0
# 18   buy  43367.0  40577.0 -2790.0      5294.0
# 19   buy  39754.0  38829.0  -925.0      4369.0
# 20   buy  38977.0  38878.0   -99.0      4270.0

# %%
import seaborn as sns

sns.lineplot(data = df["cum_profit"])
# Out:
# <AxesSubplot:ylabel='cum_profit'>
